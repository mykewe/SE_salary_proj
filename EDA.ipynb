# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')
df.head()
# Out:
#                        Job Title             Salary Estimate  \
# 0      Software Quality Engineer  £49K-£55K (Glassdoor Est.)
# 1  Senior Software Test Engineer  £49K-£55K (Glassdoor Est.)
# 2     Software Engineer Graduate  £49K-£55K (Glassdoor Est.)
# 3              Software Engineer  £49K-£55K (Glassdoor Est.)
# 4              Software Engineer  £49K-£55K (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Are you looking for a new opportunity to gain ...     3.0
# 1  Overview:\nSolarWinds MSP is the leading globa...     3.8
# 2  Software Engineer Graduate, Stevenage\n\nPLEAS...     4.0
# 3  Software Engineer\n\nOverview\n\nWe are curren...     3.6
# 4  See yourself being part of a large, transforma...     4.2
#
#        Company Name                   Location               Headquarters  \
# 0  XLN Telecom\n3.0         Sheffield, England     London, United Kingdom
# 1   SolarWinds\n3.8        Edinburgh, Scotland                 Austin, TX
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'mean_salary', 'company_txt', 'job_city',
#        'job_country', 'isjobinHQ', 'age', 'python', 'html', 'javascript',
#        'java', 'cpp', 'sql', 'aws', 'C', 'css', 'scala', 'matlab', 'ML',
#        'job_simp', 'desc_len', 'comp_count'],
#       dtype='object')

# %%
df['company_txt']
# Out:
# 0                      XLN Telecom\n
# 1                       SolarWinds\n
# 2                             MBDA\n
# 3                         Cygilant\n
# 4                            IRESS\n
#                    ...
# 965                 Rakuten France\n
# 966                           OPUS\n
# 967                 FinancialForce\n
# 968               Oscar Associates\n
# 969    Newton Colmore Consulting Ltd
# Name: company_txt, Length: 970, dtype: object

# %%
df['company_txt'] = df.company_txt.apply(lambda x: str(x).replace('\n',''))
df['company_txt']
# Out:
# 0                        XLN Telecom
# 1                         SolarWinds
# 2                               MBDA
# 3                           Cygilant
# 4                              IRESS
#                    ...
# 965                   Rakuten France
# 966                             OPUS
# 967                   FinancialForce
# 968                 Oscar Associates
# 969    Newton Colmore Consulting Ltd
# Name: company_txt, Length: 970, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded  min_salary  max_salary  mean_salary  \
# count  970.000000   970.000000  970.000000  970.000000   970.000000
# mean     3.399072  1550.390722   39.628866   54.690722    47.159794
# std      1.742769   826.660215   10.027125   15.634077    12.584400
# min     -1.000000    -1.000000   22.000000   31.000000    28.000000
# 25%      3.400000  1880.000000   32.000000   40.000000    36.000000
# 50%      3.900000  1998.000000   43.000000   58.000000    50.500000
# 75%      4.300000  2009.000000   43.000000   61.000000    52.000000
# max      5.000000  2020.000000   71.000000  110.000000    90.500000
#
#         isjobinHQ         age      python        html  javascript  ...  \
# count  970.000000  970.000000  970.000000  970.000000  970.000000  ...
# mean     0.374227   23.518557    0.407216    0.089691    0.271134  ...
# std      0.484172   39.251645    0.491569    0.285886    0.444774  ...
# ...

# %%
df.Rating.hist()

# %%
df.mean_salary.hist()

# %%
df.age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column =['age','Rating','mean_salary'])

# %%
corr=df[['age','Rating','mean_salary','desc_len','comp_count']].corr()

# %%
print(corr)
# Out:
#                   age    Rating  mean_salary  desc_len  comp_count
# age          1.000000  0.152655    -0.022345  0.096381    0.249855
# Rating       0.152655  1.000000     0.062408  0.238850    0.215717
# mean_salary -0.022345  0.062408     1.000000  0.035747    0.026433
# desc_len     0.096381  0.238850     0.035747  1.000000    0.267161
# comp_count   0.249855  0.215717     0.026433  0.267161    1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr,vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'mean_salary', 'company_txt', 'job_city',
#        'job_country', 'isjobinHQ', 'age', 'python', 'html', 'javascript',
#        'java', 'cpp', 'sql', 'aws', 'C', 'css', 'scala', 'matlab', 'ML',
#        'job_simp', 'desc_len', 'comp_count'],
#       dtype='object')

# %%
cat_cols = ['Location', 'Headquarters', 'Size', 
       'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
        'company_txt', 'job_city','job_country', 'isjobinHQ', 'python', 'html', 'javascript',
       'java', 'cpp', 'sql', 'aws', 'C', 'css', 'scala', 'matlab', 'ML',
       'job_simp']

# %%
df_cat = df[cat_cols]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart=sns.barplot(x=cat_num.index, y= cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 117
# graph for Headquarters: total = 154
# graph for Size: total = 9
# graph for Type of ownership: total = 11
# graph for Industry: total = 55
# graph for Sector: total = 21
# graph for Revenue: total = 13
# graph for Competitors: total = 116
# graph for company_txt: total = 403
# graph for job_city: total = 115
# graph for job_country: total = 22
# graph for isjobinHQ: total = 2
# graph for python: total = 2
# graph for html: total = 2
# graph for javascript: total = 2
# graph for java: total = 2
# graph for cpp: total = 2
# graph for sql: total = 2
# graph for aws: total = 2
# graph for C: total = 2
# graph for css: total = 2
# graph for scala: total = 2
# graph for matlab: total = 2
# graph for ML: total = 2
# graph for job_simp: total = 9

# %%
for i in df_cat[['Location', 'Headquarters', 'Industry', 'Competitors','company_txt', 'job_city']]:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart=sns.barplot(x=cat_num.index, y= cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for Industry: total = 20
# graph for Competitors: total = 20
# graph for company_txt: total = 20
# graph for job_city: total = 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'mean_salary', 'company_txt', 'job_city',
#        'job_country', 'isjobinHQ', 'age', 'python', 'html', 'javascript',
#        'java', 'cpp', 'sql', 'aws', 'C', 'css', 'scala', 'matlab', 'ML',
#        'job_simp', 'desc_len', 'comp_count'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'job_simp', values = 'mean_salary').sort_values('mean_salary', ascending = False)
# Out:
#            mean_salary
# job_simp
# frontend     49.375000
# na           47.698753
# cpp          47.500000
# fullstack    46.333333
# Devops       45.500000
# backend      44.937500
# data         44.923077
# java         44.883721
# python       42.282609

# %%
pd.pivot_table(df, index = 'Location', values = 'mean_salary').sort_values('mean_salary', ascending = False)
# Out:
#                                             mean_salary
# Location
# North Walsham, England                            90.50
# Wideopen, England                                 90.50
# Ruddington, England                               77.00
# Shipley, Yorkshire and the Humber, England        71.50
# Newcastle upon Tyne, England                      71.25
# ...                                                 ...
# Thames Ditton, England                            29.50
# Stockton-on-Tees, England                         29.50
# City of London, England                           29.50
# Sunningdale, England                              28.00
# Stokesley, England                                28.00
#
# [117 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'mean_salary', 'company_txt', 'job_city',
#        'job_country', 'isjobinHQ', 'age', 'python', 'html', 'javascript',
#        'java', 'cpp', 'sql', 'aws', 'C', 'css', 'scala', 'matlab', 'ML',
#        'job_simp', 'desc_len', 'comp_count'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'comp_count', 'python', 'html', 'javascript',
       'java', 'cpp', 'sql', 'aws', 'C', 'css', 'scala', 'matlab', 'ML','Type of ownership','mean_salary']]

# %%
for i in df_pivots.columns[:-1]:
    print(i)
    print(pd.pivot_table(df_pivots,index =i, values = 'mean_salary').sort_values('mean_salary', ascending = False))
# Out:
# Rating
#         mean_salary
# Rating
#  2.6      64.500000
#  1.9      63.500000
#  4.6      58.857143
#  3.0      55.666667
#  2.0      52.500000
#  2.2      52.500000
#  4.8      50.846154
#  3.5      50.275862
#  4.7      50.273973
#  4.3      49.916667
#  2.4      49.000000
#  5.0      48.546296
#  3.8      48.310606
#  4.2      48.098485
#  3.3      47.291667
#  4.1      47.228814
#  4.4      46.770833
#  3.4      46.547619
#  3.9      46.178082
#  4.0      46.040698
# -1.0      45.508264
#  2.5      45.500000
#  3.1      45.300000
#  3.7      44.792683
#  3.6      44.589744
#  3.2      44.062500
#  4.9      43.560000
#  2.7      42.750000
#  2.9      41.944444
#  4.5      40.545455
#  2.8      39.500000
# Industry
#                                          mean_salary
# Industry
# Research & Development                     90.500000
# Security Services                          71.500000
# Cable, Internet & Telephone Providers      71.250000
# ...

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

# %%
plt.figure(figsize=[10,10])
plt.imshow(wc)
plt.axis('off')
plt.show()
